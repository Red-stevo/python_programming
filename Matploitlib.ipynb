# %%
import matplotlib.pyplot as ppt
import numpy as np

ppt.plot(np.linspace(12, 67, 100), np.linspace(0,19, 100))
ppt.xlabel("Random values in X-axis.")
ppt.ylabel("Random value in Y-axis")
ppt.title("Random Plot")
ppt.show()
